# %% [markdown]
# # Data Analysis Challenges
# If at any point you have any questions, feel free to ask Dr. Angelo or Daisy.
#
# As always, feel free to use the official pandas documentation [which can be found here](https://pandas.pydata.org/docs/), and the official matplotlib documentation [which can be found here](https://matplotlib.org/contents.html).

# %% [markdown]
# ## 1. Import the .csv file and turn it into a Pandas dataframe, then display the dataframe
# Bonus points if you know what csv stands for!

# %% [markdown]
# ## 2. Getting more information on our data
# ### 2.1. Find out the datatype of all of the information in our dataframe

# %% [markdown]
# ### 2.2. Find the number of entries, mean, standard deviation, and quartiles for each column

# %% [markdown]
# ### 2.3. Access the first ten rows of two columns of your choosing

# %% [markdown]
# ### 2.4. Find the maximum value of every column

# %% [markdown]
# ### 2.5. Find the maximum value of only one specified column

# %% [markdown]
# ### 2.6. Get all of the column mames

# %% [markdown]
# ### 2.7. Get a list of values of everything

# %% [markdown]
# ## 3. Sort the data
# ### 3.1. Sort the data according to a specific column in ascending order

# %% [markdown]
# ### 3.1. Sort the data according to a specific column in descending order

# %% [markdown]
# ## 4. Graph the data
# Be ready to present this graph to the class! Be creative with what you graph, and how you graph, as well as what you take from the graph.
